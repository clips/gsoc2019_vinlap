# %%
import pandas as pd
import seaborn as sns

import unicodedata
from langdetect import detect
import langid
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer

import numpy as np
import nltk
from nltk import bigrams
import itertools
import networkx as nx

import matplotlib.pyplot as plt

# %%
#Class created to preprocess the text of the tweets and get the tokens

class TextProcessor():

    def __init__(self):
        pass

    def detect_language(self, text):
        return detect(text)

    def fast_detect_language(self, text):
        return langid.classify(text)[0]

    def remove_accents(self, text):
        # remove accents in text
        #if isinstance(text, unicode):
        text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore')
        return text
        #return text


    def remove_hashtags(self, text):
        regex = r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)"  # hash-tags
        text = re.sub(regex, ' ', text)
        return text


    def remove_mentions(self, text):
        regex = r'@[^\s]+'  # remove @-mentions
        text = re.sub(regex, ' ', text)
        return text


    def remove_urls(self, text):
        regex = r'http\S+'  # remove url
        text = re.sub(regex, ' ', text.decode('utf-8'))
        return text


    def remove_punctuation(self, text):
        # r'[.]',#remove points
        regex = r'[%s]' % re.escape(string.punctuation)  # signsPattern
        text = re.sub(regex, ' ', text)
        return text


    def remove_special_issues(self, text):
        regex_issues = [r'haha*', r'hehe*', r'[0-5][7-9]*']
        for regex in regex_issues:
            text = re.sub(regex, ' ', text)
        return text


    def remove_stop_words(self, tokens):
        stop = stopwords.words('english')
        return [token for token in tokens if token not in stop]


    def normalize_vocals(self, text):
        re.sub(r'a*', 'a', text)
        re.sub(r'e*', 'e', text)
        re.sub(r'i*', 'i', text)
        re.sub(r'o*', 'o', text)
        re.sub(r'u*', 'u', text)
        return text


    def stemming(self, tokens):
        return self.stemmer.apply(tokens)


    def tokenization(self, text):
        # this function pre-process de text of a tweet return a list of tokens
        tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)
        text = text.lower()  # text to lower
        text = text.rstrip('\n')
        text = self.remove_accents(text)  # remove accents
        text = self.remove_urls(text)  # remove urls
        text = self.remove_punctuation(text)  # remove sign puntuation
        text = self.remove_special_issues(text)
        text = self.normalize_vocals(text)
        tokens = tknzr.tokenize(text)

        tokens = self.remove_stop_words(tokens)  # remove stop words

        tokens = [token for token in tokens if len(token) > 2]
        text = " ".join(tokens)

        return text

# %%
#Read the dataset
maga = pd.read_excel("the MAGA corpus.xlsx",index_col=0)

# %%
#Choose a theme
repvsdem = maga[maga["Theme"]=="Republicans vs Democrats"]

# %%
#Preprocess the text of the tweet
tp = TextProcessor()
repvsdem["processed_tweet"] = repvsdem["Tweet"].apply(lambda x: tp.tokenization(x).split())
# Out:
# c:\users\ramse\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Generate the chains with a co_ocurrence matrix
def generate_co_occurrence_matrix(corpus):
    vocab = set(corpus)
    vocab = list(vocab)
    vocab_index = {word: i for i, word in enumerate(vocab)}
 
    # Create bigrams from all words in corpus
    bi_grams = list(bigrams(corpus))
 
    # Frequency distribution of bigrams ((word1, word2), num_occurrences)
    bigram_freq = nltk.FreqDist(bi_grams).most_common(len(bi_grams))
 
    # Initialise co-occurrence matrix
    # co_occurrence_matrix[current][previous]
    co_occurrence_matrix = np.zeros((len(vocab), len(vocab)))
 
    # Loop through the bigrams taking the current and previous word,
    # and the number of occurrences of the bigram.
    for bigram in bigram_freq:
        current = bigram[0][1]
        previous = bigram[0][0]
        count = bigram[1]
        pos_current = vocab_index[current]
        pos_previous = vocab_index[previous]
        co_occurrence_matrix[pos_current][pos_previous] = count
    co_occurrence_matrix = np.matrix(co_occurrence_matrix)
 
    # return the matrix and the index
    return co_occurrence_matrix, vocab_index
 
text_data = repvsdem["processed_tweet"].to_list()
 
# Create one list using many lists
data = list(itertools.chain.from_iterable(text_data))
matrix, vocab_index = generate_co_occurrence_matrix(data)
 
df = pd.DataFrame(matrix, index=vocab_index,
                             columns=vocab_index)

# %%
#Creation of  a graph to get the spanning trees that will generate chains for the visualization

source = []
target = []
weight = []
for i in range(len(idx)):
    weight.append(matrix[idx[i],idy[i]])
    source.append(list(vocab_index.keys())[idx[i]])   
    target.append(list(vocab_index.keys())[idy[i]])

# %%
edges = pd.DataFrame({'source':source,'target': target,'weight':weight})
G = nx.from_pandas_edgelist(edges, edge_attr=True)

# %%
# That's it. You can search any word here and will give you the chains of words
X = nx.dfs_successors(G,"realdonaldtrump")

# %%
#This as json will create the sunburst visualization
X
# Out:
# {'realdonaldtrump': ['without'],
#  'without': ['hired'],
#  'hired': ['hunt'],
#  'hunt': ['plain'],
#  'plain': ['shirts'],
#  'shirts': ['disgusting'],
#  'disgusting': ['separating'],
#  'separating': ['stop'],
#  'stop': ['wont'],
#  'wont': ['wrong'],
#  'wrong': ['doubt'],
#  'doubt': ['wga'],
#  'wga': ['maga'],
#  'maga': ['amnesty',
#   'retiredcdnrjb',
#   'tkewalt',
#   'thelastscout',
#   'dtruth',
#   'seinfeld',
#   'cuck',
#   'worldwide',
#   'tagging',
#   'therendernba',
#   'reploubarletta',
#   'hashtagginf',
#   'vakruta',
#   'realization',
#   'carminezozzora',
#   'amysuds',
#   'julia',
#   'trumpconspired',
#   'justicedems',
#   'veritasvirtusx',
#   'emmakennedy',
#   'cantaloupenews',
#   'richdborges',
#   'kayajones',
#   'lasvegas',
#   'joefreedomlove',
#   'mcmickey',
#   'karxnka',
#   'thejordanrachel',
#   'poldeek',
#   'superracist',
#   'kimdotcom',
#   'bettierose',
#   'trusttheprocess',
#   'judirymer'],
#  'amnesty': ['immediate'],
#  'immediate': ['deserve'],
#  'deserve': ['doesnt', 'cambridge'],
#  'doesnt': ['putin'],
#  'putin': ['roll', 'icj', 'debleg'],
#  'roll': ['eye'],
#  'eye': ['half'],
#  'half': ['realized'],
#  'realized': ['living'],
#  'living': ['uspoli'],
#  'uspoli': ['nooneisillegal'],
#  'nooneisillegal': ['nomorerape'],
#  'nomorerape': ['nomoreabuse'],
#  'nomoreabuse': ['notonemore'],
#  'notonemore': ['neveragain'],
#  'neveragain': ['guncontrol'],
#  'guncontrol': ['fuckthenra'],
#  'fuckthenra': ['blacklivesmatter'],
#  'blacklivesmatter': ['colinkaepernick'],
#  'colinkaepernick': ['nflplayers'],
#  'nflplayers': ['resistance'],
#  'resistance': ['disorder'],
#  'disorder': ['thomas'],
#  'thomas': ['realjameswoods', 'apprentice'],
#  'realjameswoods': ['judgemoroz', 'impeachbarry'],
#  'judgemoroz': ['get'],
#  'get': ['middle', 'sucked'],
#  'middle': ['corner', 'paragraph'],
#  'corner': ['painting'],
#  'painting': ['cnn'],
#  'cnn': ['anchor', 'channelj', 'sarahcwestwood', 'somewhat'],
#  'anchor': ['trump'],
#  'trump': ['presidency',
#   'acute',
#   'distraction',
#   'putintrump',
#   'reykjaviking',
#   'slimeball',
#   'putininthecity',
#   'realdonalbtrump',
#   'prediction',
#   'istandwithtrump',
#   'releaseyourtaxes',
#   'scold'],
#  'presidency': ['end'],
#  'end': ['shitshow'],
#  'shitshow': ['whitehouse'],
#  'whitehouse': ['donaldtrump'],
#  'donaldtrump': ['next', 'johnbolton', 'reverts', 'badmessagepresident'],
#  'next': ['braindamaged', 'plot'],
#  'braindamaged': ['land'],
#  'land': ['opportunity'],
#  'opportunity': ['plenty'],
#  'plenty': ['already'],
#  'already': ['greatest', 'patricepinkfile'],
#  'greatest': ['one', 'hits', 'date'],
#  'one': ['deplorable', 'gabriele', 'irishman', 'blumenthal', 'scottpresler'],
#  'deplorable': ['credit', 'nazisinthewhitehouse'],
#  'credit': ['mental'],
#  'mental': ['yet'],
#  'yet': ['masses'],
#  'masses': ['see'],
#  'see': ['dems'],
#  'dems': ['nothing'],
#  'nothing': ['senpaulryan', 'lilbulli', 'newhumanist'],
#  'senpaulryan': ['goaway'],
#  'goaway': ['trumpliesagain'],
#  'trumpliesagain': ['hillary'],
#  'hillary': ['result', 'trumpsuperpac'],
#  'result': ['party'],
#  'party': ['authoritarianism'],
#  'authoritarianism': ['grasp', 'horrors'],
#  'grasp': ['nevertrump'],
#  'nevertrump': ['blather', 'founders'],
#  'blather': ['may'],
#  'may': ['affair'],
#  'affair': ['time'],
#  'time': ['justice', 'parasitic', 'newday', 'prime'],
#  'justice': ['entire', 'rough'],
#  'entire': ['problem'],
#  'problem': ['pakistan', 'beings', 'barrygoldwate'],
#  'pakistan': ['urbannaxal', 'automatically'],
#  'urbannaxal': ['candleandbindigang'],
#  'candleandbindigang': ['tukdegang'],
#  'tukdegang': ['liblibtard'],
#  'liblibtard': ['lol', 'peas', 'nanasewdear', 'janovandersloo', 'refers'],
#  'lol': ['fear'],
#  'fear': ['enough'],
#  'enough': ['libtard'],
#  'libtard': ['pic', 'beware'],
#  'pic': ['failed'],
#  'failed': ['act', 'paxputina'],
#  'act': ['espionage'],
#  'espionage': ['violations'],
#  'violations': ['laundering'],
#  'laundering': ['money'],
#  'money': ['shall', 'transferred'],
#  'shall': ['seattletimes'],
#  'seattletimes': ['familiesbelongtogether'],
#  'familiesbelongtogether': ['bluewave'],
#  'bluewave': ['democratshateamerica', 'theatlantic'],
#  'democratshateamerica': ['bullshit', 'thofjuly', 'clintoncrimes'],
#  'bullshit': ['fuck'],
#  'fuck': ['victims', 'bofa'],
#  'victims': ['abuse'],
#  'abuse': ['process'],
#  'process': ['perhaps'],
#  'perhaps': ['ummm', 'feingold'],
#  'ummm': ['geopolitics'],
#  'geopolitics': ['much'],
#  'much': ['racist', 'apologies', 'flags', 'loathes', 'lve'],
#  'racist': ['danger', 'loathsome'],
#  'danger': ['jimmy'],
#  'jimmy': ['crimemustfall'],
#  'crimemustfall': ['fucktrump'],
#  'fucktrump': ['treasonweasel',
#   'fucksussanefromtargetaskingforthemanager',
#   'nowmypresident',
#   'noaltrightcrypto',
#   'evangelicals',
#   'liberallecter',
#   'censortrump',
#   'republiklan',
#   'immabluedot',
#   'shitballs',
#   'trumptaxes',
#   'fuckjordan',
#   'itssarcasim',
#   'ihatedonaldtrump'],
#  'treasonweasel': ['absolute'],
#  'absolute': ['abominable', 'brainer'],
#  'abominable': ['liegate'],
#  'liegate': ['sounds'],
#  'sounds': ['great'],
#  'great': ['negotiator', 'wishing', 'unifier'],
#  'negotiator': ['everybody'],
#  'everybody': ['nobel'],
#  'nobel': ['prize', 'doomed'],
#  'prize': ['cheesy'],
#  'cheesy': ['hollywood'],
#  'hollywood': ['scared'],
#  'scared': ['daily'],
#  'daily': ['ticker', 'republica'],
#  'republica': ['winning'],
#  'winning': ['never', 'richest', 'kthopkins'],
#  'never': ['isis', 'thailandcaverescue', 'danvil', 'prosper'],
#  'isis': ['nominee'],
#  'nominee': ['scotus'],
#  'scotus': ['rulings', 'selection', 'turtlehead'],
#  'rulings': ['propaganda'],
#  'propaganda': ['brain', 'spreading'],
#  'brain': ['hated', 'readjusted'],
#  'hated': ['anywhere'],
#  'anywhere': ['pope'],
#  'pope': ['like'],
#  'like': ['minded',
#   'freedomcaucus',
#   'imbeciles',
#   'connect',
#   'spoken',
#   'arseholes'],
#  'minded': ['feeble'],
#  'feeble': ['classless'],
#  'classless': ['guy'],
#  'guy': ['tamed', 'jointravisallen'],
#  'tamed': ['newsweek'],
#  'newsweek': ['hope'],
#  'hope': ['kremlin', 'firefighters'],
#  'kremlin': ['pricks'],
#  'pricks': ['diabolical'],
#  'diabolical': ['federation'],
#  'federation': ['russian'],
#  'russian': ['dictator', 'ari', 'siding'],
#  'dictator': ['becoming'],
#  'becoming': ['ready'],
#  'ready': ['cages'],
#  'cages': ['locked'],
#  'locked': ['good'],
#  'good': ['husband',
#   'seanspicer',
#   'slate',
#   'wsvn',
#   'nationalembarrasment',
#   'posthumous',
#   'sbalist',
#   'fruits',
#   'riddance'],
#  'husband': ['filed'],
#  'filed': ['charges'],
#  'charges': ['convictions'],
#  'convictions': ['going'],
#  'going': ['tell', 'lash', 'joepiscoposhow', 'rothfusforpa', 'fuel'],
#  'tell': ['supportlawenforcement', 'soon'],
#  'soon': ['prison'],
#  'prison': ['boys', 'lawbreakers'],
#  'boys': ['poor'],
#  'poor': ['leadership'],
#  'leadership': ['gave'],
#  'gave': ['shocker'],
#  'shocker': ['adultery'],
#  'adultery': ['cover', 'divorcing'],
#  'cover': ['liability'],
#  'liability': ['insurance'],
#  'insurance': ['health', 'punishing'],
#  'health': ['payer'],
#  'payer': ['single'],
#  'single': ['democrat'],
#  'democrat': ['fortunately', 'walkedaway'],
#  'fortunately': ['saracarterdc'],
#  'saracarterdc': ['tuckercarlson'],
#  'tuckercarlson': ['foxnews'],
#  'foxnews': ['jamesthompsonks',
#   'keeptalking',
#   'makada',
#   'patina',
#   'nyu',
#   'regan'],
#  'jamesthompsonks': ['dont'],
#  'dont': ['ask', 'lilithresists'],
#  'ask': ['folks', 'keyboard', 'duke'],
#  'folks': ['march'],
#  'march': ['women'],
#  'women': ['possible'],
#  'possible': ['maryrwilliams', 'possess', 'exception'],
#  'maryrwilliams': ['johnnyblkshrt'],
#  'johnnyblkshrt': ['spanish'],
#  'spanish': ['tommy'],
#  'tommy': ['robinson', 'compare'],
#  'robinson': ['jeff'],
#  'jeff': ['dissent', 'letmypeoplego'],
#  'dissent': ['patriotism'],
#  'patriotism': ['unpatriotic', 'nflpa'],
#  'unpatriotic': ['truth'],
#  'truth': ['arent', 'closer', 'familiar', 'papalpopularity', 'sole'],
#  'arent': ['careful'],
#  'careful': ['law'],
#  'law': ['taken'],
#  'taken': ['leads'],
#  'leads': ['ideal'],
#  'ideal': ['call'],
#  'call': ['taming', 'carvellwallace', 'butthurt', 'mrpresident'],
#  'taming': ['continent'],
#  'continent': ['murdering'],
#  'murdering': ['met', 'monsters'],
#  'met': ['people', 'schoolgirl'],
#  'people': ['debate',
#   'representing',
#   'getwellsoon',
#   'honey',
#   'bannerite',
#   'stoopid',
#   'thingsishouldbedoingnow',
#   'truefactsstated',
#   'daft'],
#  'debate': ['ones'],
#  'ones': ['mind'],
#  'mind': ['splitting', 'junk', 'architect'],
#  'splitting': ['suffer'],
#  'suffer': ['take', 'headaches'],
#  'take': ['course'],
#  'course': ['intermediaries', 'walrusmagazine'],
#  'intermediaries': ['pass'],
#  'pass': ['legislation'],
#  'legislation': ['control'],
#  'control': ['demoncratliars'],
#  'demoncratliars': ['let'],
#  'let': ['alone', 'repeat'],
#  'alone': ['idiots'],
#  'idiots': ['fucking', 'westvirginia'],
#  'fucking': ['demeans', 'freak', 'manchild'],
#  'demeans': ['everyone'],
#  'everyone': ['working'],
#  'working': ['realmuckmaker', 'fellowships', 'replacements'],
#  'realmuckmaker': ['makeamericagreatagain'],
#  'makeamericagreatagain': ['americafirst', 'redtowel'],
#  'americafirst': ['wwg'],
#  'wwg': ['begin', 'nowcomesthepain', 'redpill', 'patriotsunited', 'wwa'],
#  'begin': ['steps'],
#  'steps': ['two'],
#  'two': ['clearance'],
#  'clearance': ['completed', 'security'],
#  'completed': ['tasks'],
#  'security': ['meaningless'],
#  'meaningless': ['meaning'],
#  'meaning': ['learned'],
#  'learned': ['honor'],
#  'honor': ['men', 'magamyass', 'badge', 'courage'],
#  'men': ['everywhere'],
#  'everywhere': ['glock', 'dipped'],
#  'glock': ['carry'],
#  'carry': ['load', 'piece'],
#  'piece': ['paper', 'recognition'],
#  'paper': ['ballots'],
#  'ballots': ['said'],
#  'said': ['improper', 'neverthelessshepersisted'],
#  'improper': ['unprecedented'],
#  'unprecedented': ['travesty'],
#  'travesty': ['whats'],
#  'whats': ['left'],
#  'left': ['falling', 'bashes'],
#  'falling': ['wages'],
#  'wages': ['goptaxscam'],
#  'goptaxscam': ['pushed'],
#  'pushed': ['push'],
#  'push': ['hate'],
#  'hate': ['kult', 'disgustingdemoncrats'],
#  'kult': ['album'],
#  'album': ['otepofficial'],
#  'otepofficial': ['new'],
#  'new': ['finally', 'flesh', 'bon', 'endeavor'],
#  'finally': ['lately'],
#  'lately': ['town'],
#  'town': ['owns'],
#  'owns': ['world'],
#  'world': ['carmen', 'illuminatiam', 'robbed'],
#  'carmen': ['sandiego'],
#  'sandiego': ['make'],
#  'make': ['saint', 'realdonaldtrfan', 'catholicism', 'annoucement'],
#  'saint': ['patriot'],
#  'patriot': ['liarinchief', 'accuses'],
#  'liarinchief': ['crookeddonaldtrump', 'shhh'],
#  'crookeddonaldtrump': ['corruption'],
#  'corruption': ['uncover', 'bribery', 'synonymous', 'barrys'],
#  'uncover': ['would'],
#  'would': ['endorse',
#   'devastate',
#   'noway',
#   'dreamed',
#   'residents',
#   'buckley',
#   'timeline',
#   'threatened'],
#  'endorse': ['wholeheartedly'],
#  'wholeheartedly': ['thank'],
#  'thank': ['pointing', 'smarter', 'henry', 'honoring'],
#  'pointing': ['majority'],
#  'majority': ['thrusting'],
#  'thrusting': ['ireland'],
#  'ireland': ['hard'],
#  'hard': ['reason'],
#  'reason': ['assholeinchief', 'sure'],
#  'sure': ['attorney'],
#  'attorney': ['hear'],
#  'hear': ['apology', 'mkultra'],
#  'apology': ['heard'],
#  'heard': ['bwa'],
#  'bwa': ['losers'],
#  'losers': ['myheartsankwhen'],
#  'myheartsankwhen': ['libby'],
#  'libby': ['popular'],
#  'popular': ['vote'],
#  'vote': ['inauguration', 'gopracism', 'desperatedems', 'turntheothercheek'],
#  'inauguration': ['best'],
#  'best': ['luck', 'rohll', 'appointing'],
#  'luck': ['harrywho', 'socialismkills', 'nfl'],
#  'nfl': ['athletes', 'westand', 'praises'],
#  'athletes': ['knew'],
#  'knew': ['attempt', 'vlad'],
#  'attempt': ['mediocre', 'downplaying'],
#  'mediocre': ['seanhannity'],
#  'seanhannity': ['gayrepublicswag',
#   'mommydean',
#   'jtkirklin',
#   'aintwesomething'],
#  'gayrepublicswag': ['perfect'],
#  'perfect': ['storm', 'newjerseyag'],
#  'storm': ['catagory'],
#  'catagory': ['catastrofuck'],
#  'catastrofuck': ['trumpocalypse'],
#  'trumpocalypse': ['davidcorndc',
#   'bond',
#   'nytobits',
#   'itsgoodtoberaul',
#   'dancirnford'],
#  'davidcorndc': ['williamlegate'],
#  'williamlegate': ['imwithher'],
#  'imwithher': ['hillaryclinton', 'stupidfuckinglibtards'],
#  'hillaryclinton': ['walkaway', 'felonies', 'blackcatz'],
#  'walkaway': ['constitutionalrepublic',
#   'cibilsesco',
#   'pedogate',
#   'voight',
#   'stopprotectingothers',
#   'walkawayorelse'],
#  'cibilsesco': ['voiceforme'],
#  'voiceforme': ['nurse'],
#  'nurse': ['scifi'],
#  'scifi': ['wspritchett'],
#  'wspritchett': ['closernation'],
#  'closernation': ['thebestcloser', 'danrather'],
#  'thebestcloser': ['buildthewall'],
#  'buildthewall': ['words'],
#  'words': ['deportationorders'],
#  'deportationorders': ['release'],
#  'release': ['full'],
#  'full': ['yup', 'demorats', 'agreement'],
#  'yup': ['better'],
#  'better': ['life', 'tragedies', 'unions', 'supervision'],
#  'life': ['liberty', 'southerner', 'scammed', 'obscure', 'legacies'],
#  'liberty': ['freedom'],
#  'freedom': ['come', 'hellnokavanaugh'],
#  'come': ['kenya', 'dolts', 'farmaid', 'contact', 'walks'],
#  'kenya': ['born'],
#  'born': ['obama'],
#  'obama': ['phone',
#   'cough',
#   'cuomoprimetime',
#   'cleaning',
#   'slapped',
#   'frankluntz',
#   'predecessors',
#   'wingman'],
#  'phone': ['app'],
#  'app': ['walmart'],
#  'walmart': ['boycotting', 'mockery', 'davidmichwright'],
#  'boycotting': ['talk'],
#  'talk': ['yuuuge', 'supportively', 'dumbfux'],
#  'yuuuge': ['thinks'],
#  'thinks': ['ancestry', 'choose'],
#  'ancestry': ['genetics'],
#  'choose': ['gop'],
#  'gop': ['senbobcorker',
#   'manchuriancandidate',
#   'kristinminkdc',
#   'mantra',
#   'illustrious',
#   'flate',
#   'thunk',
#   'iowagop',
#   'lockerroomtalk',
#   'johnkasich',
#   'disowning',
#   'senatorlankford',
#   'reich',
#   'determined',
#   'representatives',
#   'rebrand'],
#  'senbobcorker': ['rino'],
#  'rino': ['potus'],
#  'potus': ['add',
#   'bobmenendeznj',
#   'italianbitchfit',
#   'arnoldt',
#   'americanpolitics',
#   'oann',
#   'strat',
#   'foofighters',
#   'kayleighmcenany',
#   'oust',
#   'stupidistogenerous',
#   'lietoamerica',
#   'angelicdeby',
#   'preetbharara',
#   'candidates',
#   'godbless',
#   'demokkkrazi',
#   'uncovered',
#   'behaves',
#   'abbreviated',
#   'jstagliareni',
#   'liestheytoldmewhenyoung',
#   'weareq',
#   'difficulty'],
#  'add': ['might', 'dalerboyce'],
#  'might': ['escalate'],
#  'escalate': ['republicans'],
#  'republicans': ['brilliant',
#   'blasting',
#   'specified',
#   'whatsatstake',
#   'nazigop',
#   'futurepolitician',
#   'dominant'],
#  'brilliant': ['nothings'],
#  'nothings': ['mouth'],
#  'mouth': ['shut', 'noone'],
#  'shut': ['playboy'],
#  'playboy': ['whore'],
#  'whore': ['send'],
#  'send': ['taxpayers'],
#  'taxpayers': ['class'],
#  'class': ['fathomable'],
#  'fathomable': ['cannot'],
#  'cannot': ['block', 'christofascists'],
#  'block': ['websites'],
#  'websites': ['corporations'],
#  'corporations': ['aka'],
#  'aka': ['hussian', 'enbolden'],
#  'enbolden': ['godblessvets'],
#  'godblessvets': ['vets'],
#  'vets': ['fought'],
#  'fought': ['believed'],
#  'believed': ['metoo'],
#  'metoo': ['issue', 'inclusive'],
#  'issue': ['brings'],
#  'brings': ['history'],
#  'history': ['corrupttrump', 'lesson', 'ounds', 'speakers', 'gangofputin'],
#  'corrupttrump': ['treason'],
#  'treason': ['intolerant', 'conviction', 'crumbled'],
#  'intolerant': ['tolerating'],
#  'tolerating': ['tired'],
#  'tired': ['deflection', 'tantrums'],
#  'deflection': ['sad'],
#  'sad': ['spygate', 'rubes', 'ally', 'disengaged', 'gal'],
#  'spygate': ['pooh'],
#  'pooh': ['yeah'],
#  'yeah': ['lets'],
#  'lets': ['discuss', 'societies', 'arneduncan', 'remembernone'],
#  'discuss': ['ugliness'],
#  'ugliness': ['war'],
#  'war': ['isnt', 'casualties'],
#  'isnt': ['politics'],
#  'politics': ['society'],
#  'society': ['rest'],
#  'rest': ['trumpcrimefamily'],
#  'trumpcrimefamily': ['fine', 'allmustgo'],
#  'fine': ['dandy', 'perfectly'],
#  'dandy': ['muslimiq'],
#  'perfectly': ['waltshaub'],
#  'waltshaub': ['shaub', 'melissajpeltier', 'fieldingfishly', 'suggesting'],
#  'shaub': ['walter'],
#  'melissajpeltier': ['mregan'],
#  'suggesting': ['muslims'],
#  'muslims': ['believing'],
#  'believing': ['suddenly', 'untreated'],
#  'suddenly': ['thejusticedept', 'contracted'],
#  'thejusticedept': ['fbi'],
#  'fbi': ['operative', 'assumed', 'nassaucountypd', 'rinos'],
#  'operative': ['forced'],
#  'forced': ['produce', 'bathe'],
#  'produce': ['farmers'],
#  'farmers': ['porch', 'bribing', 'organic', 'benifit'],
#  'porch': ['guzzling'],
#  'guzzling': ['tea'],
#  'tea': ['sweet', 'leaves'],
#  'sweet': ['air', 'smell', 'toddstarnes', 'super'],
#  'smell': ['dncplantation'],
#  'super': ['power', 'hauntedcoconut'],
#  'power': ['taxing', 'perceived'],
#  'taxing': ['per'],
#  'per': ['pay'],
#  'pay': ['sandwich', 'polluting', 'hush', 'raises', 'fines'],
#  'sandwich': ['bus'],
#  'bus': ['ride'],
#  'ride': ['maybe'],
#  'maybe': ['someday'],
#  'someday': ['way'],
#  'way': ['bend',
#   'girlfriends',
#   'upholding',
#   'honoured',
#   'rowling',
#   'singe',
#   'trumplibtard'],
#  'bend': ['conform'],
#  'conform': ['liberal'],
#  'liberal': ['divorced',
#   'arss',
#   'disposition',
#   'theologically',
#   'listens',
#   'psychosis',
#   'emasculation',
#   'handsmaidtale',
#   'donated'],
#  'divorced': ['actress'],
#  'actress': ['alienated'],
#  'alienated': ['family'],
#  'family': ['senategop', 'gambino', 'hugs'],
#  'senategop': ['esteemed'],
#  'esteemed': ['republican'],
#  'republican': ['policies', 'nutjob'],
#  'policies': ['tradewar'],
#  'tradewar': ['tariffs', 'farmerwelfare'],
#  'tariffs': ['clueless', 'dairy'],
#  'clueless': ['chiming', 'autos'],
#  'chiming': ['topic'],
#  'topic': ['pretty'],
#  'pretty': ['pineapple', 'uses'],
#  'pineapple': ['sodomizes'],
#  'uses': ['speech'],
#  'speech': ['fbr', 'straightforward'],
#  'fbr': ['nyc', 'fbrresistance'],
#  'nyc': ['western'],
#  'western': ['destroy', 'nyer'],
#  'destroy': ['democracy'],
#  'democracy': ['survival'],
#  'survival': ['complicit'],
#  'complicit': ['ongoing'],
#  'ongoing': ['interfering'],
#  'interfering': ['drumpf'],
#  'drumpf': ['omarvaid',
#   'endfamilyseparation',
#   'thosekidsofyours',
#   'trolls',
#   'paulyd',
#   'hardlinepatriot',
#   'methodology',
#   'megwagner',
#   'reverses',
#   'wtaf',
#   'faced',
#   'pragmatism',
#   'viral',
#   'marry',
#   'republicants',
#   'foodforthought',
#   'trumpspam',
#   'inches',
#   'trumpfraud',
#   'diarrheaitis',
#   'comparison',
#   'politicususa',
#   'images',
#   'daddyimsad',
#   'flouting',
#   'allkidswithguns',
#   'throws',
#   'makingamericascaredagain',
#   'dunce',
#   'tmz',
#   'receives'],
#  'omarvaid': ['churchlady'],
#  'churchlady': ['almostastute'],
#  'almostastute': ['aclu'],
#  'aclu': ['dnc', 'scottkn'],
#  'dnc': ['trumptrainusa', 'ingrahamangle', 'snappy'],
#  'ingrahamangle': ['wattersworld'],
#  'wattersworld': ['resist'],
#  'resist': ['nytimes',
#   'carolricard',
#   'thursdaymotivation',
#   'keepfamilestogether',
#   'tuckercarlsontonight',
#   'although',
#   'hardcore',
#   'ccalnon',
#   'irelandreferendum',
#   'altgov',
#   'trumpsamerica',
#   'proudmom',
#   'politicsnation',
#   'janice',
#   'speakup'],
#  'nytimes': ['talks'],
#  'talks': ['mean'],
#  'mean': ['whining', 'kurteichenwald', 'doesent', 'shugar'],
#  'whining': ['someone', 'patriotsonly'],
#  'someone': ['superstitious', 'trigger', 'wikileaks', 'lifelong'],
#  'superstitious': ['hmmm'],
#  'hmmm': ['dear'],
#  'dear': ['red', 'godzweedz'],
#  'red': ['house', 'pill', 'carpet', 'herring'],
#  'house': ['notjustice', 'whatwillittake', 'portrait', 'falls'],
#  'notjustice': ['policenotnazis'],
#  'policenotnazis': ['wherearethechildren'],
#  'wherearethechildren': ['donald', 'fucktheborderpatrol'],
#  'donald': ['supporter', 'duck'],
#  'supporter': ['real'],
#  'real': ['meaningful', 'vivaresistance', 'farmacist'],
#  'meaningful': ['diplomacy'],
#  'diplomacy': ['dishonors'],
#  'dishonors': ['america'],
#  'america': ['patriotnation',
#   'megaphone',
#   'shutitdown',
#   'sahilkapur',
#   'electrical',
#   'dedication',
#   'saddam',
#   'freemarket',
#   'gilded',
#   'devalues',
#   'zealots',
#   'governs',
#   'latin',
#   'fleeing',
#   'noprivatetrumpputinsitdown'],
#  'patriotnation': ['wethepeople'],
#  'wethepeople': ['want', 'repay', 'gelles'],
#  'want': ['strip',
#   'envy',
#   'taketothestreets',
#   'thebluehousekr',
#   'hollyshitwoods',
#   'misspoke',
#   'claimed',
#   'winstoncovfefe'],
#  'strip': ['trying'],
#  'trying': ['convince',
#   'assert',
#   'muster',
#   'cling',
#   'transparent',
#   'tiffanyclay'],
#  'assert': ['authority'],
#  'authority': ['moral'],
#  'moral': ['decency', 'rightness'],
#  'decency': ['disgrace'],
#  'disgrace': ['tiny', 'bestatbeingworst'],
#  'tiny': ['kimjongun', 'teeny', 'suck'],
#  'kimjongun': ['koreans'],
#  'koreans': ['north'],
#  'north': ['korea', 'greenville'],
#  'korea': ['realdailywire', 'syria'],
#  'realdailywire': ['well'],
#  'well': ['kids', 'mannered', 'progressing', 'aging'],
#  'kids': ['away', 'crickets'],
#  'away': ['thegoodgodabove', 'chipping', 'pop', 'gunpoint'],
#  'thegoodgodabove': ['sayeth'],
#  'sayeth': ['allmighty'],
#  'allmighty': ['argue'],
#  'argue': ['used'],
#  'used': ['bludgeon', 'fastandfurious', 'loosely', 'exotic'],
#  'bludgeon': ['conservatives'],
#  'conservatives': ['irs'],
#  'irs': ['orders'],
#  'orders': ['chanting'],
#  'chanting': ['lock'],
#  'lock': ['private'],
#  'private': ['recruited', 'transcripts', 'email'],
#  'recruited': ['criminals'],
#  'criminals': ['impeachtrump'],
#  'impeachtrump': ['clean',
#   'friyay',
#   'nohate',
#   'johnzajaros',
#   'voteoutgop',
#   'civildisobedience',
#   'happiness',
#   'appointee',
#   'notacompliment',
#   'regret',
#   'therewasnosentence',
#   'arresttrump',
#   'kingdom',
#   'trumpfuckery',
#   'bonehead',
#   'robertmueller',
#   'trumprussiacoverup',
#   'convicttrump',
#   'eatawholebagofdicks',
#   'needtoimpeach',
#   'crookedtrump',
#   'goppartyovercountry',
#   'ihatetrump',
#   'sethmacfarlane'],
#  'clean': ['employment'],
#  'employment': ['social', 'chamber'],
#  'social': ['coward', 'safeguards', 'supplementing'],
#  'coward': ['intellectual'],
#  'intellectual': ['become', 'wackadoos'],
#  'become': ['apathetic', 'thrives'],
#  'apathetic': ['sits'],
#  'sits': ['congress'],
#  'congress': ['defunded',
#   'boycottfascism',
#   'mccreadyfornc',
#   'appalled',
#   'watts',
#   'enables',
#   'preaching'],
#  'defunded': ['election'],
#  'election': ['dispicable', 'reduced', 'ohgov'],
#  'dispicable': ['win'],
#  'win': ['issues'],
#  'issues': ['voters', 'ignorent', 'readily'],
#  'voters': ['agenda', 'swing', 'confim'],
#  'agenda': ['domestic'],
#  'domestic': ['minimize', 'takeover'],
#  'minimize': ['race'],
#  'race': ['claims'],
#  'claims': ['joybehar', 'jobless', 'sexualharassment'],
#  'jobless': ['june'],
#  'june': ['happens'],
#  'happens': ['hes', 'corrupted'],
#  'hes': ['reality', 'ave', 'goss'],
#  'reality': ['porn', 'alternate'],
#  'porn': ['paid'],
#  'paid': ['head'],
#  'head': ['various', 'bullet', 'kickstarter'],
#  'various': ['londonist'],
#  'londonist': ['via'],
#  'via': ['appropriated',
#   'tpm',
#   'huffpostpol',
#   'cnnmoney',
#   'influences',
#   'chrisenloe'],
#  'appropriated': ['funds'],
#  'funds': ['judges'],
#  'judges': ['economy'],
#  'economy': ['kill', 'cdnpoli', 'crashes'],
#  'kill': ['threatening'],
#  'threatening': ['safety'],
#  'safety': ['school'],
#  'school': ['taught'],
#  'taught': ['children'],
#  'children': ['easily', 'bordersecurity', 'bath', 'sicko'],
#  'easily': ['confused'],
#  'confused': ['assholes', 'depressed'],
#  'assholes': ['homophobes', 'gullible'],
#  'gullible': ['whipped'],
#  'whipped': ['votethemout'],
#  'votethemout': ['lockthemup', 'manafortjailed', 'familesbelongtogether'],
#  'lockthemup': ['notmypresident'],
#  'notmypresident': ['dennisridenour',
#   'dynasty',
#   'dearnonnatives',
#   'vicentefoxque',
#   'tuckfrump',
#   'fascistpigtrump',
#   'sight',
#   'readjust',
#   'weinstein',
#   'familiesbelongtogther',
#   'nitwit',
#   'stophim',
#   'kardashian',
#   'ironman',
#   'logicrules'],
#  'dennisridenour': ['ill'],
#  'ill': ['wasting',
#   'ordering',
#   'tharambe',
#   'honetweeter',
#   'kacy',
#   'tbt',
#   'devincomiskey',
#   'obamalegacy'],
#  'ordering': ['bolten'],
#  'bolten': ['invite'],
#  'invite': ['president'],
#  'president': ['partys',
#   'thankq',
#   'obligated',
#   'woo',
#   'exaggerates',
#   'succeed',
#   'finalized',
#   'trumpglish',
#   'enrich'],
#  'partys': ['failure'],
#  'failure': ['put'],
#  'put': ['category', 'perpetually', 'solitary'],
#  'perpetually': ['ineffective'],
#  'ineffective': ['stillwithering'],
#  'stillwithering': ['tuesdaythoughts'],
#  'tuesdaythoughts': ['qanon', 'graphs'],
#  'qanon': ['trumpville',
#   'mcga',
#   'ruffrican',
#   'safepassage',
#   'endthedeepstate',
#   'australia',
#   'hooray'],
#  'mcga': ['cathmckenna', 'elite', 'chizmaga', 'greggutfeld'],
#  'cathmckenna': ['greenonfund'],
#  'elite': ['global', 'globalist'],
#  'global': ['decisions'],
#  'decisions': ['idiocy'],
#  'idiocy': ['sop'],
#  'sop': ['altright'],
#  'altright': ['ordinary'],
#  'ordinary': ['intermediary'],
#  'intermediary': ['cipher'],
#  'cipher': ['kkk'],
#  'kkk': ['entirely'],
#  'entirely': ['democrats'],
#  'democrats': ['othe',
#   'willing',
#   'communicated',
#   'deranged',
#   'krem',
#   'inactivity',
#   'oxymoron',
#   'crybabies',
#   'outstanding',
#   'atheist',
#   'expects',
#   'learns',
#   'complacent',
#   'fiverights',
#   'bettymccollum',
#   'btch'],
#  'willing': ['negotiate', 'devotee'],
#  'negotiate': ['kurtschlichter'],
#  'kurtschlichter': ['know'],
#  'know': ['supporters',
#   'electing',
#   'sissies',
#   'jackasshole',
#   'catch',
#   'katy',
#   'flub',
#   'manders',
#   'chihuahuafirst',
#   'redpainter',
#   'kristenoliver',
#   'capacity',
#   'motherfuckers',
#   'teamtrump',
#   'hireaveteranday',
#   'manipulators',
#   'seanastin',
#   'dazed',
#   'parenting',
#   'dopes'],
#  'supporters': ['enchanted', 'feeding'],
#  'enchanted': ['todays'],
#  'todays': ['vulgarity'],
#  'vulgarity': ['lies'],
#  'lies': ['crap',
#   'bonnie',
#   'shat',
#   'missingchildren',
#   'shspresssec',
#   'unpopularisanunderstatement',
#   'contradictions'],
#  'crap': ['fucker'],
#  'fucker': ['jesus'],
#  'jesus': ['coming', 'alpolitics'],
#  'coming': ['collude', 'amd', 'atrocious', 'americanfascism', 'commonwealth'],
#  'collude': ['russia'],
#  'russia': ['soviet',
#   'collaborate',
#   'commited',
#   'flying',
#   'acknowledges',
#   'comrades',
#   'boltontoinviteputintodc',
#   'mentioning',
#   'putinvictorytour'],
#  'soviet': ['senjohnmccain'],
#  'senjohnmccain': ['resigned'],
#  'resigned': ['jeffflake'],
#  'jeffflake': ['members'],
#  'members': ['seriously'],
#  'seriously': ['wtf', 'illness', 'amirite', 'organ', 'lickspittle'],
#  'wtf': ['help'],
#  'help': ['busting'],
#  'busting': ['colorado'],
#  'colorado': ['union'],
#  'union': ['aidachavez'],
#  'aidachavez': ['wow'],
#  'wow': ['letter', 'unity', 'asachildithought'],
#  'letter': ['reading'],
#  'reading': ['says'],
#  'says': ['tweets', 'stevekbannon', 'earnest', 'mobile', 'barackdiditbetter'],
#  'tweets': ['compile', 'potusknows', 'hugin', 'successive', 'coorelate'],
#  'compile': ['file'],
#  'file': ['need', 'dox'],
#  'need': ['banned',
#   'rollback',
#   'pink',
#   'egomaniac',
#   'faltering',
#   'intriguing',
#   'addicted',
#   'tedcruz',
#   'compromise',
#   'denial'],
#  'banned': ['effective'],
#  'effective': ['argument'],
#  'argument': ['emotional'],
#  'emotional': ['winner'],
#  'winner': ['news'],
#  'news': ['cbs', 'cycles', 'host', 'channel', 'sycophant'],
#  'cbs': ['nbc'],
#  'nbc': ['payrolls'],
#  'payrolls': ['accuse'],
#  'accuse': ['everything'],
#  'everything': ['michelle', 'fraudtrump', 'blamed', 'insist', 'frickin'],
#  'michelle': ['employing'],
#  'employing': ['proud'],
#  'proud': ['fellow', 'sue', 'comprehension', 'tweeps'],
#  'fellow': ['fascists'],
#  'fascists': ['right'],
#  'right': ['front',
#   'albeit',
#   'abort',
#   'whatnow',
#   'sanity',
#   'continued',
#   'womans',
#   'nipple'],
#  'front': ['lead', 'kicks'],
#  'lead': ['star'],
#  'star': ['kind'],
#  'kind': ['unredeemable', 'comical', 'bowel', 'liblibtarded'],
#  'unredeemable': ['sociopath'],
#  'sociopath': ['removed'],
#  'removed': ['impeached', 'craniums'],
#  'impeached': ['abt'],
#  'abt': ['cares'],
#  'cares': ['advancement'],
#  'advancement': ['citizens'],
#  'citizens': ['held'],
#  'held': ['jews', 'jughead'],
#  'jews': ['millions'],
#  'millions': ['caused'],
#  'caused': ['humans', 'dddoom'],
#  'humans': ['vile'],
#  'vile': ['fake', 'pattonoswalt', 'grandchildrens'],
#  'fake': ['tan',
#   'magazine',
#   'blankenship',
#   'disprove',
#   'awards',
#   'afterward',
#   'phonyflotus'],
#  'tan': ['capped'],
#  'capped': ['teeth'],
#  'teeth': ['big'],
#  'big': ['fuckyou', 'millennial', 'mac', 'reiterate', 'nificent', 'contract'],
#  'fuckyou': ['helm', 'moron'],
#  'moron': ['david', 'babbling'],
#  'david': ['institutions'],
#  'institutions': ['sacred'],
#  'sacred': ['distrust', 'trampling'],
#  'distrust': ['unrest'],
#  'unrest': ['creating'],
#  'creating': ['straight'],
#  'straight': ['king'],
#  'king': ['peter'],
#  'peter': ['strzok'],
#  'strzok': ['wife'],
#  'wife': ['ohr', 'cheated'],
#  'cheated': ['pageants'],
#  'pageants': ['beauty'],
#  'beauty': ['tom', 'obsessed'],
#  'tom': ['peeping'],
#  'peeping': ['predator'],
#  'predator': ['sexual'],
#  'sexual': ['deviancy'],
#  'deviancy': ['yes'],
#  'yes': ['directed',
#   'israelfirst',
#   'craigdf',
#   'rotflmao',
#   'sailor',
#   'resistancewave'],
#  'directed': ['ending'],
#  'ending': ['korean', '8yrs', 'painful', 'exciting'],
#  'korean': ['served'],
#  'served': ['patriotically', 'turns'],
#  'patriotically': ['valiantly'],
#  'turns': ['made'],
#  'made': ['career',
#   'bankers',
#   'jasonlewis',
#   'iphones',
#   'berniesanders',
#   'brasilmagic'],
#  'career': ['joke', 'swindling'],
#  'joke': ['paedophilia', 'funnier'],
#  'paedophilia': ['else'],
#  'else': ['hurled'],
#  'hurled': ['hateful'],
#  'hateful': ['devil'],
#  'devil': ['rotten'],
#  'rotten': ['fish', 'core'],
#  'fish': ['stinks'],
#  'core': ['encased', 'leftists'],
#  'encased': ['brittle'],
#  'brittle': ['shell'],
#  'leftists': ['progressives', 'looney'],
#  'progressives': ['hill'],
#  'hill': ['city'],
#  'city': ['los', 'penthouse'],
#  'los': ['angeles'],
#  'angeles': ['deciding'],
#  'deciding': ['california'],
#  'california': ['state', 'libturds'],
#  'state': ['dontvote',
#   'mates',
#   'ers',
#   'county',
#   'bibledoesnotbelongingovernnent',
#   'scheme'],
#  'dontvote': ['jaz'],
#  'jaz': ['somebody', 'notinmycali'],
#  'somebody': ['confidence'],
#  'confidence': ['consumer'],
#  'consumer': ['economys'],
#  'economys': ['era'],
#  'era': ['rule'],
#  'rule': ['publicity', 'imposing'],
#  'publicity': ['making'],
#  'making': ['cheaper', 'thump'],
#  'cheaper': ['expense'],
#  'expense': ['richer', 'public'],
#  'richer': ['ooh'],
#  'ooh': ['poors'],
#  'public': ['intellectuals',
#   'dolibtard',
#   'obliged',
#   'damning',
#   'antithesis',
#   'lauded'],
#  'dolibtard': ['branding', 'despise'],
#  'branding': ['ploy'],
#  'ploy': ['bad'],
#  'bad': ['norwegian', 'heinously', 'qkode'],
#  'norwegian': ['candy'],
#  'candy': ['obviously'],
#  'obviously': ['attracted', 'lwnj'],
#  'attracted': ['size'],
#  'size': ['wallet', 'albiet'],
#  'wallet': ['despite'],
#  'despite': ['overwhelming'],
#  'overwhelming': ['favor'],
#  'favor': ['run'],
#  'run': ['wealthy', 'hilary', 'crook', 'winningright'],
#  'wealthy': ['damned'],
#  'damned': ['thing', 'dtbechtol'],
#  'thing': ['personal', 'sorta', 'goddamn', 'shielding'],
#  'personal': ['preference', 'hurling', 'profit'],
#  'preference': ['scotusnomination'],
#  'scotusnomination': ['scotuspick'],
#  'scotuspick': ['scotusnominee'],
#  'scotusnominee': ['limericks'],
#  'limericks': ['thelimpdick'],
#  'thelimpdick': ['limerick'],
#  'limerick': ['kamalaharris'],
#  'kamalaharris': ['support'],
#  'support': ['appreciate',
#   'egalitarian',
#   'elicit',
#   'mrdane',
#   'midgets',
#   'potuspoker',
#   'stablegeniusfl'],
#  'appreciate': ['mass'],
#  'mass': ['enron', 'shredding'],
#  'enron': ['pardon'],
#  'pardon': ['presidential', 'poem', 'rosie'],
#  'presidential': ['pardons', 'cleaned', 'enact'],
#  'pardons': ['impeach'],
#  'impeach': ['latimes',
#   'itsmuellertime',
#   'combined',
#   'ruleoflaw',
#   'merch',
#   'blowhard'],
#  'latimes': ['considering'],
#  'considering': ['revoking'],
#  'revoking': ['brennan'],
#  'brennan': ['john'],
#  'john': ['mccain', 'galt'],
#  'mccain': ['flake', 'american'],
#  'american': ['farm', 'idol', 'sendavidperdue', 'serves', 'strength'],
#  'farm': ['bot'],
#  'bot': ['non'],
#  'non': ['whites'],
#  'whites': ['aspiring', 'classes'],
#  'aspiring': ['always'],
#  'always': ['count', 'skew', 'merica'],
#  'count': ['successes', 'unless', 'muricans'],
#  'unless': ['illegal'],
#  'illegal': ['drugs', 'deported'],
#  'drugs': ['along'],
#  'along': ['borders', 'gutter', 'clearnace', 'filth'],
#  'borders': ['sir', 'empower', 'extermination'],
#  'sir': ['prayers', 'hello'],
#  'prayers': ['thoughts'],
#  'thoughts': ['today'],
#  'today': ['marks',
#   'wounded',
#   'veteransresist',
#   'pressconference',
#   'clapping',
#   'breakfast',
#   'shower',
#   'usefulidiot',
#   'censoring'],
#  'marks': ['fourth'],
#  'fourth': ['day'],
#  'day': ['watch', 'scare', 'television', 'wolveyjohnson', 'dwindling'],
#  'watch': ['treat', 'stories', 'myendoftheworldtheory'],
#  'treat': ['poorly', 'vfwhq'],
#  'poorly': ['sarcasm'],
#  'sarcasm': ['quote'],
#  'quote': ['appropriate'],
#  'appropriate': ['terribly', 'describe'],
#  'terribly': ['written'],
#  'written': ['fiction'],
#  'fiction': ['bebest'],
#  'bebest': ['thamendment'],
#  'thamendment': ['outfits', 'bars'],
#  'outfits': ['matching'],
#  'bars': ['behind'],
#  'behind': ['scenes', 'fuckers', 'unassailable'],
#  'scenes': ['allowing'],
#  'allowing': ['less'],
#  'less': ['blackpeople', 'male', 'notme', 'frequently', 'menacing'],
#  'blackpeople': ['drown'],
#  'male': ['black'],
#  'black': ['unemployment', 'boxer', 'arresting'],
#  'unemployment': ['record', 'hispanic'],
#  'record': ['avowed', 'productive', 'conduct'],
#  'avowed': ['white'],
#  'white': ['chubby',
#   'gayconservative',
#   'supremist',
#   'supremacy',
#   'supremacist',
#   'males',
#   'nationalist',
#   'reigned',
#   'nameless'],
#  'supremist': ['slogan'],
#  'slogan': ['theresistance'],
#  'theresistance': ['chrismurphyct',
#   'controversial',
#   'amaze',
#   'jasonwalston',
#   'orwhatever',
#   'thisisnews'],
#  'chrismurphyct': ['draintheswamp'],
#  'draintheswamp': ['unus', 'drainthedeepstate', 'wwjd', 'moto'],
#  'unus': ['sumus'],
#  'sumus': ['faktczech'],
#  'faktczech': ['gaymafia'],
#  'gaymafia': ['ninox'],
#  'drainthedeepstate': ['deepstate'],
#  'deepstate': ['doj'],
#  'doj': ['paying'],
#  'paying': ['placate', 'mil', 'trumpwall', 'davidarquette', 'owed'],
#  'mil': ['sparklebroom', 'tobias'],
#  'sparklebroom': ['guns'],
#  'guns': ['buy'],
#  'buy': ['flotus', 'island', 'varneyco', 'rubbish'],
#  'flotus': ['stephgrisham', 'bigkissesfromgermany', 'pamb', 'elegance'],
#  'stephgrisham': ['repealobama'],
#  'repealobama': ['thanksobama'],
#  'thanksobama': ['succeeded'],
#  'succeeded': ['ever'],
#  'ever': ['seen',
#   'tolerant',
#   'intend',
#   'vandalized',
#   'cnnfakenews',
#   'strongest',
#   'prrsident'],
#  'seen': ['setback'],
#  'setback': ['biggest'],
#  'biggest': ['liars', 'systematic', 'hoax'],
#  'liars': ['start'],
#  'start': ['sliding', 'disarming', 'preparing'],
#  'sliding': ['hell'],
#  'hell': ['relax',
#   'demonrats',
#   'sold',
#   'ofsocialism',
#   'beer',
#   'benefited',
#   'prosecutetrump'],
#  'sold': ['tapes'],
#  'tapes': ['vhs', 'eleven', 'pee', 'prospects', 'vcr'],
#  'pee': ['tape'],
#  'tape': ['strengthen'],
#  'strengthen': ['base'],
#  'base': ['drumpfism', 'eats', 'chunk', 'unreachable'],
#  'drumpfism': ['period'],
#  'period': ['commonsense', 'lawlessness'],
#  'commonsense': ['using'],
#  'using': ['cower', 'drawl', 'corporation', 'spelling'],
#  'cower': ['protect'],
#  'protect': ['elections', 'aim'],
#  'elections': ['electbonneau', 'systems', 'interfered'],
#  'systems': ['weapon'],
#  'weapon': ['kinds'],
#  'kinds': ['troubles'],
#  'troubles': ['rogue'],
#  'rogue': ['actors'],
#  'actors': ['foreign'],
#  'foreign': ['agent', 'carmakers'],
#  'agent': ['conspiring'],
#  'conspiring': ['trumpputin'],
#  'trumpputin': ['afcnviolet'],
#  'afcnviolet': ['immoralreport'],
#  'immoralreport': ['alyssa'],
#  'alyssa': ['pirana', 'milano'],
#  'pirana': ['posus'],
#  'milano': ['hollyweird'],
#  'hollyweird': ['another', 'fad', 'beens'],
#  'another': ['broken',
#   'intention',
#   'vegans',
#   'ironstache',
#   'obrador',
#   'groupthink',
#   'whiny'],
#  'broken': ['oath', 'kfile'],
#  'oath': ['naturalization', 'testify'],
#  'testify': ['agreed'],
#  'agreed': ['garbagetrump', 'micropenis', 'trumprussiacollusion'],
#  'garbagetrump': ['fakepotus'],
#  'trumprussiacollusion': ['cohenflipped', 'transitioned', 'madness'],
#  'transitioned': ['officially'],
#  'officially': ['invited'],
#  'invited': ['room', 'fill', 'purim'],
#  'room': ['underage'],
#  'underage': ['prostitutes'],
#  'prostitutes': ['urinate'],
#  'urinate': ['defecate', 'bed'],
#  'bed': ['say'],
#  'say': ['merrick',
#   'impossible',
#   'lowiq',
#   'benjamin',
#   'constructive',
#   'monsanto',
#   'thirds',
#   'ppact',
#   'faked',
#   'gmo'],
#  'merrick': ['garland'],
#  'impossible': ['bipartisanship'],
#  'bipartisanship': ['makes'],
#  'makes': ['subtle', 'unfitforoffice', 'corrupts'],
#  'subtle': ['impact'],
#  'impact': ['even'],
#  'even': ['discount',
#   'hireamerican',
#   'farther',
#   'rigging',
#   'buddies',
#   'extreme',
#   'fucktwit',
#   'grateful',
#   'decade',
#   'sank',
#   'milk',
#   'nowthisnews',
#   'dies',
#   'qualify'],
#  'discount': ['hertz'],
#  'hertz': ['expensive'],
#  'expensive': ['rental'],
#  'rental': ['companies'],
#  'companies': ['didnt', 'bankrupted'],
#  'didnt': ['break'],
#  'break': ['ins', 'charlieamter'],
#  'ins': ['unusual'],
#  'unusual': ['collusion'],
#  'collusion': ['meeting',
#   'nramoney',
#   'trrump',
#   'gaslighting',
#   'poser',
#   'gangsta',
#   'russisn',
#   'delusion',
#   'russion',
#   'burger',
#   'quisling',
#   'russiancollaborators',
#   'chummy',
#   'schiff',
#   'trumpcollusion'],
#  'meeting': ['canceled', 'reprimand', 'privately'],
#  'canceled': ['neverkerry'],
#  'neverkerry': ['exist'],
#  'exist': ['military', 'pluralism'],
#  'military': ['personnel',
#   'bigredonefirstinfantryvietnam',
#   'bases',
#   'appreciating',
#   'memorialday',
#   'industrial',
#   'coordination',
#   'snipers'],
#  'personnel': ['cnns'],
#  'cnns': ['chooses'],
#  'chooses': ['continues', 'surgeon'],
#  'continues': ['spew', 'crumble'],
#  'spew': ['filthy'],
#  'filthy': ['slaps', 'emulate'],
#  'slaps': ['tight'],
#  'emulate': ['shouldnt'],
#  'shouldnt': ['anyones', 'country'],
#  'country': ['uniting',
#   'defund',
#   'club',
#   'indivisible',
#   'chains',
#   'tending',
#   'protects',
#   'flowing',
#   'civilized',
#   'enter',
#   'sacrifice',
#   'darkleft',
#   'shanka',
#   'governor'],
#  'uniting': ['movement', 'smh'],
#  'movement': ['americas'],
#  'americas': ['longer', 'molding'],
#  'longer': ['useful', 'abcsupplydsm', 'applies'],
#  'useful': ['wet'],
#  'wet': ['fart'],
#  'fart': ['unbelievably'],
#  'unbelievably': ['childish'],
#  'childish': ['hey'],
#  'hey': ['meathead',
#   'facism',
#   'mollymckew',
#   'chelseaclinton',
#   'grabthembythepussy',
#   'cunt',
#   'stappelizabeth',
#   'cnnnewsroom',
#   'doofus',
#   'emolumentsclause',
#   'douchebag',
#   'hip'],
#  'meathead': ['leftist'],
#  'leftist': ['tools', 'limolib'],
#  'tools': ['loosing'],
#  'loosing': ['damn'],
#  'damn': ['office', 'richarddawkins'],
#  'office': ['nuclear',
#   'tarnished',
#   'dishonoured',
#   'menace',
#   'repugs',
#   'persons',
#   'urgently',
#   'atheism',
#   'pussypower',
#   'leak'],
#  'nuclear': ['upped', 'increase', 'arsenals', 'production', 'holocaust'],
#  'increase': ['oil'],
#  'oil': ['prices'],
#  'prices': ['mondaymotivation'],
#  'mondaymotivation': ['fight'],
#  'fight': ['unborn',
#   'mamma',
#   'makecongressblueagain',
#   'theyhateus',
#   'ontariondp'],
#  'unborn': ['killing', 'imposes'],
#  'killing': ['kidnapper', 'hundreds', 'sponsored', 'tribe'],
#  'kidnapper': ['childmolester'],
#  'childmolester': ['iyad'],
#  'iyad': ['elbaghdadi'],
#  'hundreds': ['color'],
#  'color': ['gopchairwoman', 'days'],
#  'gopchairwoman': ['newdayfornj'],
#  'newdayfornj': ['horseshort'],
#  'horseshort': ['bilwil'],
#  'bilwil': ['cvsjr'],
#  'cvsjr': ['huginfornj'],
#  'huginfornj': ['freesamhyde'],
#  'days': ['row', 'ear', 'finding'],
#  'row': ['asked'],
#  'asked': ['wanker', 'consent'],
#  'wanker': ['thought'],
#  'thought': ['wed', 'forking', 'elton', 'cryn'],
#  'wed': ['bet'],
#  'bet': ['thatll', 'cared', 'safe'],
#  'safe': ['progressive', 'relatively'],
#  'progressive': ['fantasized'],
#  'fantasized': ['encouraged'],
#  'encouraged': ['violence'],
#  'violence': ['wear', 'caliconsrvative', 'acted'],
#  'wear': ['columbiabugle'],
#  'columbiabugle': ['redwaverising'],
#  'redwaverising': ['trumpstariffs',
#   'redvote',
#   'democratsarecorrupt',
#   'trustinhim'],
#  'trumpstariffs': ['hurting'],
#  'hurting': ['countries', 'divisiveness'],
#  'countries': ['helped', 'quarterfinalist', 'thole'],
#  'helped': ['recruitment'],
#  'recruitment': ['dumptrump'],
#  'dumptrump': ['avenattidossier',
#   'paulryanthinkswearedumb',
#   'berylmom',
#   'jwhittenbergk',
#   'sendtrumptorussia',
#   'spygateisfakenews',
#   'sexualpredatortrump',
#   'avenattitime',
#   'proceedings',
#   'marinesagainsttrump',
#   'shithead',
#   'trumpets',
#   'sewer',
#   'scumster',
#   'educatethemasses',
#   'mitchmcconnelisaturtle',
#   'flagonofwhine'],
#  'avenattidossier': ['nowrongavenatti'],
#  'nowrongavenatti': ['basta'],
#  ...}
